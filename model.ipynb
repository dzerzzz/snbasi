# %%
import os
import cv2
import time
import random
import numpy as np

import tensorflow as tf
from tensorflow.keras.applications.inception_v3 import preprocess_input
from tensorflow.keras import layers, metrics
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.applications import Xception
from tensorflow.keras.models import Model, Sequential

from sklearn.metrics import accuracy_score, confusion_matrix
import seaborn as sns
import matplotlib.pyplot as plt
import pickle

# %%
# Planting
random.seed(5)
np.random.seed(5)
tf.random.set_seed(5)

# # Global variables
LFW = "LFW"
LFW_DATASET_CHANGED = os.path.join(LFW, "lfw_changed")
DATA_PATH = LFW_DATASET_CHANGED
DATASETS = "Datasets"
TRAIN_DATASETS_PATH = os.path.join(DATASETS, "trainDataset")
TEST_DATASETS_PATH = os.path.join(DATASETS, "testDataset")
TRAIN_TRIPLETS_PATH = os.path.join(DATASETS, "trainTriplets")
TEST_TRIPLETS_PATH = os.path.join(DATASETS, "testTriplets")

CHECKPOINT_PATH = 'Checkpoints'
ENCODER_SAVE_PATH = 'Encoder'

EMBEDDING_SAVE_PATH = os.path.join(CHECKPOINT_PATH, "embedding")
EMBEDDING_BEST_SAVE_PATH = os.path.join(CHECKPOINT_PATH, "embedding_best")
SIAMESE_MODEL_SAVE_PATH = os.path.join(CHECKPOINT_PATH, "siamese_model")
SIAMESE_MODEL_BEST_SAVE_PATH = os.path.join(CHECKPOINT_PATH, "siamese_model_best")
TEST_METRICS_PATH = os.path.join(CHECKPOINT_PATH, "testMetrics")
TRAIN_LOSS_PATH = os.path.join(CHECKPOINT_PATH, "trainLoss")

IMAGE_SIZE = 250

# %%
def getTriplets(directory, foldersList, max=10):
  triplets = []
  folders = list(foldersList.keys())
  
  for folder in folders:
    path = os.path.join(directory, folder)
    files = list(os.listdir(path))[:max]
    filesAmount = len(files)
      
    for i in range(filesAmount-1):
      for j in range(i+1, filesAmount):
        anchor = (folder, f"{i}.jpg")
        positive = (folder, f"{j}.jpg")

        # As long as negative folder is the same as anchor's folder other choose random folder
        negativeFolder = folder
        while negativeFolder == folder:
          negativeFolder = random.choice(folders)
        negativeFile = random.randint(0, foldersList[negativeFolder]-1)
        negative = (negativeFolder, f"{negativeFile}.jpg")

        triplets.append((anchor, positive, negative))
          
  random.shuffle(triplets)
  return triplets

# %%
def readImageForGetTripletsBatchMethod(path):
  path = os.path.join(DATA_PATH, path[0], path[1])
  print(path)
  image = cv2.imread(path)
  image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
  return image

# Keep in mind size
def getTripletsBatch(tripletsList, size=256):
  triplets = (len(tripletsList) // size) + 1

  for i in range(triplets):
    anchor   = []
    positive = []
    negative = []
    
    j = i * size
    while ( j < (i + 1) * size ) and ( j < len(tripletsList) ):
      anch, pos, neg = tripletsList[j]
      anchor.append(readImageForGetTripletsBatchMethod(anch))
      positive.append(readImageForGetTripletsBatchMethod(pos))
      negative.append(readImageForGetTripletsBatchMethod(neg))
      j += 1

    anchor = preprocess_input(np.array(anchor))
    positive = preprocess_input(np.array(positive))
    negative = preprocess_input(np.array(negative))

    yield ([anchor, positive, negative])

# %%
def getEmbedding(inputShape):
  XceptionModel = Xception(
    input_shape=inputShape,
    weights='imagenet',
    include_top=False,
    pooling='avg'
  )
  
  for i in range(len(XceptionModel.layers) - 27):
    XceptionModel.layers[i].trainable = False

  model = Sequential([
    XceptionModel,
    layers.Flatten(),
    layers.Dense(512, activation='relu'),
    layers.BatchNormalization(),
    layers.Dense(256, activation="relu"),
    layers.Lambda(lambda x: tf.math.l2_normalize(x, axis=1))
  ], name="Embedding")

  return model

# %%
ambe = getEmbedding((IMAGE_SIZE, IMAGE_SIZE, 3))
ambe.summary()
# Out:
# Model: "Embedding"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ xception (Functional)           │ ?                      │    20,861,480 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten_2 (Flatten)             │ ?                      │   0 (unbuilt) │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_4 (Dense)                 │ ?                      │   0 (unbuilt) │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_14          │ ?                      │   0 (unbuilt) │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_5 (Dense)                 │ ?                      │   0 (unbuilt) │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ lambda_2 (Lambda)               │ ?                      │   0 (unbuilt) │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 20,861,480 (79.58 MB)
#  Trainable params: 8,402,360 (32.05 MB)
#  Non-trainable params: 12,459,120 (47.53 MB)

# %%
def extractEmbedding(model):
  embedding = getEmbedding((IMAGE_SIZE, IMAGE_SIZE, 3))
  i=0
  for embbeddingLayer in model.layers[0].layers[3].layers:
    layer_weight = embbeddingLayer.get_weights()
    embedding.layers[i].set_weights(layer_weight)
    i += 1

  return embedding

# %%
def ModelMetrics(positives, negatives):
  true = np.array([0] * len(positives) + [1] * len(negatives))
  predicted = np.append(positives, negatives)
  
  print(f"\nAccuracy of model: {accuracy_score(true, predicted)}\n")  
  confusionMatrix = confusion_matrix(true, predicted)
  categories  = ['Similar', 'Different']
  names = ['Exected Similar', 'Unexpected Similar', 'Unexpected Different', 'Exected Different']
  percentages = ['{0:.2%}'.format(value) for value in confusionMatrix.flatten() / np.sum(confusionMatrix)]

  labels = [(str(v1) + "\n" + str(v2)) for v1, v2 in zip(names, percentages)]
  labels = np.asarray(labels).reshape(2, 2)

  sns.heatmap(confusionMatrix, annot=labels, cmap='Blues', fmt='', xticklabels=categories, yticklabels=categories)
  plt.xlabel("Predicted", fontdict={'size':14}, labelpad=10)
  plt.ylabel("Actual", fontdict={'size':14}, labelpad=10)
  plt.title ("Confusion Matrix", fontdict={'size':18}, pad=20)

# %%
def classifyImages(anchorList, evaluationList, embedding, threshold=1.3):
  anchorTensor = embedding.predict(anchorList)
  evaluationTensor = embedding.predict(evaluationList)
  
  distance = np.sum(np.square(anchorTensor - evaluationTensor), axis=-1)
  prediction = np.where(distance <= threshold, 0, 1)

  return prediction

# %%
def trainSiameseModel(trainDataset, testTriplets, epochs=10, batchSize=256):
  max_acc=0
  trainLoss = []
  testMetrics = []

  for epoch in range(1, epochs+1):
    t = time.time()
    epochLoss = []
    for data in getTripletsBatch(trainTriplets, size=batchSize):
      loss = siameseModel.train_on_batch(data)
      epochLoss.append(loss)
    epochLoss = sum(epochLoss)/len(epochLoss)
    trainLoss.append(epochLoss)

    print(f"\nEPOCH: {epoch} \t (Done in: {int(time.time()-t)} sec)")
    print(f"Train Loss = {epochLoss:.5f}")
    
    # Test on test data
    metric = testOnTriplets(testTriplets, size=batchSize)
    testMetrics.append(metric)
    accuracy = metric[0]
    
    # Save new best weights and embedding model
    if accuracy>=max_acc:
      siameseModel.save_weights(SIAMESE_MODEL_BEST_SAVE_PATH)
      max_acc = accuracy
      embedding = extractEmbedding(siameseModel)
      embedding.save_weights(EMBEDDING_BEST_SAVE_PATH)

  # Save weoghts and embedding model
  siameseModel.save_weights(SIAMESE_MODEL_SAVE_PATH)
  embedding = extractEmbedding(siameseModel)
  embedding.save_weights(EMBEDDING_SAVE_PATH)

  loadedTestMetrics = []
  loadedTrainLoss = []
  #  load train loss and test metrics to add and save new ones (if possible)
  try:
    with open(TEST_METRICS_PATH, 'rb') as input:
      loadedTestMetrics = pickle.load(input)
    with open(TRAIN_LOSS_PATH, 'rb') as input:
      loadedTrainLoss = pickle.load(input)
  except:
    print("Could not load test metrics or train loss for file. It probabely doesn't exist")
  
  # Add new data to existing one 
  loadedTestMetrics += (testMetrics)
  loadedTrainLoss += (trainLoss)
  
  # Save old (if exists) + new data or just new data
  with open(TEST_METRICS_PATH, 'wb') as output:
    pickle.dump(loadedTestMetrics, output)
  with open(TRAIN_LOSS_PATH, 'wb') as output:
    pickle.dump(loadedTrainLoss, output)

  # Notice it is only new data
  testMetrics = np.array(testMetrics)
  plotMetrics(trainLoss, testMetrics)

# %%
def plotMetrics(loss, metrics):
  accuracy = metrics[:, 0]
  anchorPositiveMean  = metrics[:, 1]
  anchorNegativeMean  = metrics[:, 2]
  anchorPositiveStds  = metrics[:, 3]
  anchorNegativeStds  = metrics[:, 4]
  
  plt.figure(figsize=(15,5))
  
  # Plott loss over epochs
  plt.subplot(121)
  plt.plot(loss, 'b', label='Loss')
  plt.title('Training loss')
  plt.legend()
  
  # Plott accuracy over epochs
  plt.subplot(122)
  plt.plot(accuracy, 'r', label='Accuracy')
  plt.title('Testing Accuracy')
  plt.legend()
  
  plt.figure(figsize=(15,5))
  
  # Compare means over epochs
  plt.subplot(121)
  plt.plot(anchorPositiveMean, 'b', label='AP Mean')
  plt.plot(anchorNegativeMean, 'g', label='AN Mean')
  plt.title('Means Comparision')
  plt.legend()
  
  # Plott accuracy
  ap_75quartile = (anchorPositiveMean + anchorPositiveStds)
  an_75quartile = (anchorNegativeMean - anchorNegativeStds)
  plt.subplot(122)
  plt.plot(ap_75quartile, 'b', label='AP (Mean+SD)')
  plt.plot(an_75quartile, 'g', label='AN (Mean-SD)')
  plt.title('75th Quartile Comparision')
  plt.legend()

# %%
# Load train and test triplets
with open(TRAIN_TRIPLETS_PATH, 'rb') as input:
  trainTriplets = pickle.load(input)
with open(TEST_TRIPLETS_PATH, 'rb') as input:
  testTriplets = pickle.load(input)

# %%
trainSiameseModel(trainDataset, testTriplets, epochs=2)
# Out:
# LFW\lfw_changed\Michael_Jordan\2.jpg
# LFW\lfw_changed\Michael_Jordan\1.jpg
# LFW\lfw_changed\Steven_Spielberg\3.jpg
# LFW\lfw_changed\Paula_Radcliffe\2.jpg
# LFW\lfw_changed\Paula_Radcliffe\3.jpg
# LFW\lfw_changed\Kelly_Clarkson\1.jpg
# LFW\lfw_changed\Richard_Gere\6.jpg
# LFW\lfw_changed\Richard_Gere\0.jpg
# LFW\lfw_changed\Samuel_Waksal\1.jpg
# LFW\lfw_changed\Lucio_Gutierrez\0.jpg
# LFW\lfw_changed\Lucio_Gutierrez\5.jpg
# LFW\lfw_changed\Pedro_Almodovar\1.jpg
# LFW\lfw_changed\Frank_Solich\3.jpg
# LFW\lfw_changed\Frank_Solich\0.jpg
# LFW\lfw_changed\Robert_Evans\2.jpg
# LFW\lfw_changed\Robert_Kocharian\2.jpg
# LFW\lfw_changed\Robert_Kocharian\3.jpg
# LFW\lfw_changed\Enrique_Bolanos\3.jpg
# LFW\lfw_changed\Igor_Ivanov\6.jpg
# LFW\lfw_changed\Igor_Ivanov\7.jpg
# LFW\lfw_changed\Ken_Macha\0.jpg
# LFW\lfw_changed\John_Abizaid\4.jpg
# LFW\lfw_changed\John_Abizaid\0.jpg
# LFW\lfw_changed\Xanana_Gusmao\1.jpg
# LFW\lfw_changed\Gerhard_Schroeder\1.jpg
# LFW\lfw_changed\Gerhard_Schroeder\8.jpg
# LFW\lfw_changed\Ana_Guevara\6.jpg
# LFW\lfw_changed\Angelina_Jolie\0.jpg
# LFW\lfw_changed\Angelina_Jolie\2.jpg
# LFW\lfw_changed\Yashwant_Sinha\4.jpg
# LFW\lfw_changed\Tommy_Haas\3.jpg
# LFW\lfw_changed\Tommy_Haas\1.jpg
# LFW\lfw_changed\Michael_Chiklis\4.jpg
# LFW\lfw_changed\Halle_Berry\5.jpg
# LFW\lfw_changed\Halle_Berry\6.jpg
# LFW\lfw_changed\Isabella_Rossellini\0.jpg
# LFW\lfw_changed\Angelina_Jolie\3.jpg
# LFW\lfw_changed\Angelina_Jolie\8.jpg
# LFW\lfw_changed\Gene_Robinson\0.jpg
# LFW\lfw_changed\Megawati_Sukarnoputri\5.jpg
# LFW\lfw_changed\Megawati_Sukarnoputri\1.jpg
# LFW\lfw_changed\Roy_Williams\0.jpg
# LFW\lfw_changed\Paul_Bremer\0.jpg
# LFW\lfw_changed\Paul_Bremer\5.jpg
# LFW\lfw_changed\Jennifer_Lopez\16.jpg
# LFW\lfw_changed\Robert_Redford\4.jpg
# LFW\lfw_changed\Robert_Redford\5.jpg
# LFW\lfw_changed\Emanuel_Ginobili\3.jpg
# LFW\lfw_changed\Roberto_Carlos\0.jpg
# LFW\lfw_changed\Roberto_Carlos\1.jpg
# LFW\lfw_changed\Donald_Rumsfeld\84.jpg
# LFW\lfw_changed\Anna_Kournikova\4.jpg
# LFW\lfw_changed\Anna_Kournikova\0.jpg
# LFW\lfw_changed\Dan_Morales\0.jpg
# LFW\lfw_changed\Meryl_Streep\1.jpg
# LFW\lfw_changed\Meryl_Streep\7.jpg
# LFW\lfw_changed\Jean-Francois_Pontal\2.jpg
# LFW\lfw_changed\George_Robertson\4.jpg
# LFW\lfw_changed\George_Robertson\2.jpg
# LFW\lfw_changed\Cindy_Crawford\0.jpg
# LFW\lfw_changed\Cesar_Gaviria\2.jpg
# LFW\lfw_changed\Cesar_Gaviria\4.jpg
# LFW\lfw_changed\Bill_Callahan\2.jpg
# LFW\lfw_changed\Gerry_Adams\4.jpg
# LFW\lfw_changed\Gerry_Adams\3.jpg
# LFW\lfw_changed\Lino_Oviedo\2.jpg
# LFW\lfw_changed\Ian_Thorpe\4.jpg
# LFW\lfw_changed\Ian_Thorpe\7.jpg
# LFW\lfw_changed\Nabil_Shaath\0.jpg
# LFW\lfw_changed\Angelina_Jolie\4.jpg
# LFW\lfw_changed\Angelina_Jolie\6.jpg
# LFW\lfw_changed\Paul_ONeill\1.jpg
# LFW\lfw_changed\Julianne_Moore\0.jpg
# LFW\lfw_changed\Julianne_Moore\7.jpg
# LFW\lfw_changed\Pete_Sampras\12.jpg
# LFW\lfw_changed\Nancy_Pelosi\0.jpg
# LFW\lfw_changed\Nancy_Pelosi\3.jpg
# LFW\lfw_changed\John_Negroponte\2.jpg
# LFW\lfw_changed\John_Howard\8.jpg
# LFW\lfw_changed\John_Howard\7.jpg
# LFW\lfw_changed\Cruz_Bustamante\4.jpg
# LFW\lfw_changed\Heidi_Fleiss\2.jpg
# LFW\lfw_changed\Heidi_Fleiss\1.jpg
# LFW\lfw_changed\Tom_Reilly\2.jpg
# LFW\lfw_changed\Sylvester_Stallone\1.jpg
# LFW\lfw_changed\Sylvester_Stallone\0.jpg
# LFW\lfw_changed\Milo_Maestrecampo\1.jpg
# LFW\lfw_changed\Cameron_Diaz\3.jpg
# LFW\lfw_changed\Cameron_Diaz\1.jpg
# LFW\lfw_changed\Keanu_Reeves\7.jpg
# LFW\lfw_changed\Mohammad_Khatami\5.jpg
# LFW\lfw_changed\Mohammad_Khatami\2.jpg
# LFW\lfw_changed\Luis_Ernesto_Derbez_Bautista\3.jpg
# LFW\lfw_changed\Spencer_Abraham\8.jpg
# LFW\lfw_changed\Spencer_Abraham\2.jpg
# LFW\lfw_changed\Robert_De_Niro\2.jpg
# LFW\lfw_changed\Joschka_Fischer\2.jpg
# LFW\lfw_changed\Joschka_Fischer\4.jpg
# LFW\lfw_changed\Ricardo_Lagos\23.jpg
# LFW\lfw_changed\John_Kerry\1.jpg
# LFW\lfw_changed\John_Kerry\7.jpg
# LFW\lfw_changed\Dennis_Kucinich\3.jpg
# LFW\lfw_changed\Nestor_Kirchner\8.jpg
# LFW\lfw_changed\Nestor_Kirchner\2.jpg
# LFW\lfw_changed\William_Bratton\2.jpg
# LFW\lfw_changed\Richard_Armitage\2.jpg
# LFW\lfw_changed\Richard_Armitage\4.jpg
# LFW\lfw_changed\William_Bratton\2.jpg
# LFW\lfw_changed\JK_Rowling\1.jpg
# LFW\lfw_changed\JK_Rowling\3.jpg
# LFW\lfw_changed\Richard_Virenque\4.jpg
# LFW\lfw_changed\Alvaro_Uribe\7.jpg
# LFW\lfw_changed\Alvaro_Uribe\0.jpg
# LFW\lfw_changed\Heizo_Takenaka\7.jpg
# LFW\lfw_changed\Nestor_Kirchner\5.jpg
# LFW\lfw_changed\Nestor_Kirchner\8.jpg
# LFW\lfw_changed\Keanu_Reeves\6.jpg
# LFW\lfw_changed\Jeb_Bush\2.jpg
# LFW\lfw_changed\Jeb_Bush\8.jpg
# LFW\lfw_changed\George_Pataki\0.jpg
# LFW\lfw_changed\John_Negroponte\7.jpg
# LFW\lfw_changed\John_Negroponte\8.jpg
# LFW\lfw_changed\Nan_Wang\2.jpg
# LFW\lfw_changed\Luiz_Inacio_Lula_da_Silva\4.jpg
# LFW\lfw_changed\Luiz_Inacio_Lula_da_Silva\8.jpg
# LFW\lfw_changed\Coretta_Scott_King\1.jpg
# LFW\lfw_changed\Jay_Garner\1.jpg
# LFW\lfw_changed\Jay_Garner\4.jpg
# LFW\lfw_changed\Gene_Robinson\4.jpg
# LFW\lfw_changed\Jose_Serra\1.jpg
# LFW\lfw_changed\Jose_Serra\7.jpg
# LFW\lfw_changed\Valery_Giscard_dEstaing\4.jpg
# LFW\lfw_changed\Jackie_Chan\6.jpg
# LFW\lfw_changed\Jackie_Chan\2.jpg
# LFW\lfw_changed\James_Cunningham\2.jpg
# LFW\lfw_changed\Bill_McBride\7.jpg
# LFW\lfw_changed\Bill_McBride\1.jpg
# LFW\lfw_changed\Eileen_Coparropa\2.jpg
# LFW\lfw_changed\Keanu_Reeves\1.jpg
# LFW\lfw_changed\Keanu_Reeves\0.jpg
# LFW\lfw_changed\Michael_Caine\3.jpg
# LFW\lfw_changed\John_Manley\0.jpg
# LFW\lfw_changed\John_Manley\2.jpg
# LFW\lfw_changed\Daniel_Radcliffe\0.jpg
# LFW\lfw_changed\George_Clooney\0.jpg
# LFW\lfw_changed\George_Clooney\3.jpg
# LFW\lfw_changed\Aicha_El_Ouafi\1.jpg
# LFW\lfw_changed\Condoleezza_Rice\8.jpg
# LFW\lfw_changed\Condoleezza_Rice\3.jpg
# LFW\lfw_changed\Noelle_Bush\2.jpg
# LFW\lfw_changed\Kate_Hudson\5.jpg
# LFW\lfw_changed\Kate_Hudson\4.jpg
# LFW\lfw_changed\Phan_Van_Khai\1.jpg
# LFW\lfw_changed\Pedro_Almodovar\0.jpg
# LFW\lfw_changed\Pedro_Almodovar\3.jpg
# LFW\lfw_changed\Silvan_Shalom\0.jpg
# LFW\lfw_changed\Javier_Solana\8.jpg
# LFW\lfw_changed\Javier_Solana\0.jpg
# LFW\lfw_changed\Hamid_Karzai\9.jpg
# LFW\lfw_changed\Jesse_Jackson\0.jpg
# LFW\lfw_changed\Jesse_Jackson\4.jpg
# LFW\lfw_changed\Coretta_Scott_King\2.jpg
# LFW\lfw_changed\Sharon_Osbourne\1.jpg
# LFW\lfw_changed\Sharon_Osbourne\0.jpg
# LFW\lfw_changed\Emmanuelle_Beart\0.jpg
# LFW\lfw_changed\Pete_Sampras\6.jpg
# LFW\lfw_changed\Pete_Sampras\2.jpg
# LFW\lfw_changed\Sarah_Jessica_Parker\4.jpg
# LFW\lfw_changed\Vincent_Brooks\2.jpg
# LFW\lfw_changed\Vincent_Brooks\4.jpg
# LFW\lfw_changed\Sonia_Gandhi\0.jpg
# LFW\lfw_changed\Michael_Chang\0.jpg
# LFW\lfw_changed\Michael_Chang\5.jpg
# LFW\lfw_changed\Sebastien_Grosjean\1.jpg
# LFW\lfw_changed\Tom_Cruise\1.jpg
# LFW\lfw_changed\Tom_Cruise\6.jpg
# LFW\lfw_changed\Jay_Leno\2.jpg
# LFW\lfw_changed\Dick_Cheney\8.jpg
# LFW\lfw_changed\Dick_Cheney\3.jpg
# LFW\lfw_changed\Taha_Yassin_Ramadan\2.jpg
# LFW\lfw_changed\Spencer_Abraham\0.jpg
# LFW\lfw_changed\Spencer_Abraham\6.jpg
# LFW\lfw_changed\Mary_Carey\3.jpg
# LFW\lfw_changed\Tommy_Thompson\1.jpg
# LFW\lfw_changed\Tommy_Thompson\8.jpg
# LFW\lfw_changed\Gary_Doer\1.jpg
# LFW\lfw_changed\Dick_Cheney\7.jpg
# LFW\lfw_changed\Dick_Cheney\1.jpg
# LFW\lfw_changed\Guillermo_Canas\0.jpg
# LFW\lfw_changed\Jose_Maria_Aznar\5.jpg
# LFW\lfw_changed\Jose_Maria_Aznar\8.jpg
# LFW\lfw_changed\Marat_Safin\2.jpg
# LFW\lfw_changed\Atal_Bihari_Vajpayee\7.jpg
# LFW\lfw_changed\Atal_Bihari_Vajpayee\5.jpg
# LFW\lfw_changed\Guillermo_Canas\1.jpg
# LFW\lfw_changed\Jason_Kidd\0.jpg
# LFW\lfw_changed\Jason_Kidd\2.jpg
# LFW\lfw_changed\Pedro_Almodovar\6.jpg
# LFW\lfw_changed\Nathalie_Baye\2.jpg
# LFW\lfw_changed\Nathalie_Baye\1.jpg
# LFW\lfw_changed\Toshihiko_Fukui\1.jpg
# LFW\lfw_changed\Amelia_Vega\5.jpg
# LFW\lfw_changed\Amelia_Vega\1.jpg
# LFW\lfw_changed\Mike_Krzyzewski\4.jpg
# LFW\lfw_changed\Jan_Ullrich\4.jpg
# LFW\lfw_changed\Jan_Ullrich\1.jpg
# LFW\lfw_changed\Robbie_Williams\1.jpg
# LFW\lfw_changed\Mark_Hurlbert\2.jpg
# LFW\lfw_changed\Mark_Hurlbert\3.jpg
# LFW\lfw_changed\Thaksin_Shinawatra\2.jpg
# LFW\lfw_changed\Justin_Leonard\1.jpg
# LFW\lfw_changed\Justin_Leonard\0.jpg
# LFW\lfw_changed\Wu_Yi\2.jpg
# LFW\lfw_changed\Jonathan_Edwards\2.jpg
# LFW\lfw_changed\Jonathan_Edwards\6.jpg
# LFW\lfw_changed\Milo_Maestrecampo\0.jpg
# LFW\lfw_changed\Alvaro_Uribe\3.jpg
# LFW\lfw_changed\Alvaro_Uribe\8.jpg
# LFW\lfw_changed\Tassos_Papadopoulos\2.jpg
# LFW\lfw_changed\Kelvin_Sampson\1.jpg
# LFW\lfw_changed\Kelvin_Sampson\0.jpg
# LFW\lfw_changed\Robert_De_Niro\3.jpg
# LFW\lfw_changed\Debra_Messing\0.jpg
# LFW\lfw_changed\Debra_Messing\1.jpg
# LFW\lfw_changed\Michael_Caine\0.jpg
# LFW\lfw_changed\Ashanti\1.jpg
# LFW\lfw_changed\Ashanti\0.jpg
# LFW\lfw_changed\Catherine_Deneuve\0.jpg
# LFW\lfw_changed\Halle_Berry\6.jpg
# LFW\lfw_changed\Halle_Berry\8.jpg
# LFW\lfw_changed\Michael_Jackson\1.jpg
# LFW\lfw_changed\Nestor_Kirchner\4.jpg
# LFW\lfw_changed\Nestor_Kirchner\7.jpg
# LFW\lfw_changed\Yevgeny_Kafelnikov\3.jpg
# LFW\lfw_changed\Walter_Mondale\6.jpg
# LFW\lfw_changed\Walter_Mondale\5.jpg
# LFW\lfw_changed\Benjamin_Netanyahu\2.jpg
# LFW\lfw_changed\Gonzalo_Sanchez_de_Lozada\8.jpg
# LFW\lfw_changed\Gonzalo_Sanchez_de_Lozada\7.jpg
# LFW\lfw_changed\Clara_Harris\1.jpg
# LFW\lfw_changed\Lance_Bass\2.jpg
# LFW\lfw_changed\Lance_Bass\1.jpg
# LFW\lfw_changed\Gus_Van_Sant\1.jpg
# LFW\lfw_changed\Gilberto_Rodriguez_Orejuela\1.jpg
# LFW\lfw_changed\Gilberto_Rodriguez_Orejuela\0.jpg
# LFW\lfw_changed\Justin_Leonard\1.jpg
# LFW\lfw_changed\Thomas_OBrien\0.jpg
# LFW\lfw_changed\Thomas_OBrien\4.jpg
# LFW\lfw_changed\Gustavo_Kuerten\0.jpg
# LFW\lfw_changed\Naomi_Watts\8.jpg
# LFW\lfw_changed\Naomi_Watts\3.jpg
# LFW\lfw_changed\Nathalie_Baye\0.jpg
# LFW\lfw_changed\Al_Sharpton\0.jpg
# LFW\lfw_changed\Al_Sharpton\4.jpg
# LFW\lfw_changed\Martha_Stewart\3.jpg
# LFW\lfw_changed\Romano_Prodi\2.jpg
# LFW\lfw_changed\Romano_Prodi\1.jpg
# LFW\lfw_changed\Joe_Nichols\1.jpg
# LFW\lfw_changed\Jean-David_Levitte\5.jpg
# LFW\lfw_changed\Jean-David_Levitte\6.jpg
# LFW\lfw_changed\Claire_Danes\2.jpg
# LFW\lfw_changed\Kevin_Costner\1.jpg
# LFW\lfw_changed\Kevin_Costner\2.jpg
# LFW\lfw_changed\Barbara_Walters\3.jpg
# LFW\lfw_changed\Alvaro_Uribe\2.jpg
# LFW\lfw_changed\Alvaro_Uribe\7.jpg
# LFW\lfw_changed\Eliane_Karp\3.jpg
# LFW\lfw_changed\James_Blake\5.jpg
# LFW\lfw_changed\James_Blake\1.jpg
# LFW\lfw_changed\Phan_Van_Khai\2.jpg
# LFW\lfw_changed\Dick_Cheney\4.jpg
# LFW\lfw_changed\Dick_Cheney\2.jpg
# LFW\lfw_changed\Pedro_Almodovar\0.jpg
# LFW\lfw_changed\Jennifer_Capriati\1.jpg
# LFW\lfw_changed\Jennifer_Capriati\6.jpg
# LFW\lfw_changed\Leonardo_DiCaprio\7.jpg
# LFW\lfw_changed\Jean_Charest\3.jpg
# LFW\lfw_changed\Jean_Charest\6.jpg
# LFW\lfw_changed\Yashwant_Sinha\0.jpg
# LFW\lfw_changed\Nancy_Pelosi\2.jpg
# LFW\lfw_changed\Nancy_Pelosi\8.jpg
# LFW\lfw_changed\Candie_Kung\3.jpg
# LFW\lfw_changed\Serena_Williams\6.jpg
# LFW\lfw_changed\Serena_Williams\4.jpg
# LFW\lfw_changed\Mary_Carey\0.jpg
# LFW\lfw_changed\Tony_Stewart\4.jpg
# LFW\lfw_changed\Tony_Stewart\3.jpg
# LFW\lfw_changed\Paul_Wellstone\2.jpg
# LFW\lfw_changed\Condoleezza_Rice\8.jpg
# LFW\lfw_changed\Condoleezza_Rice\1.jpg
# LFW\lfw_changed\Mukesh_Ambani\2.jpg
# LFW\lfw_changed\Tung_Chee-hwa\4.jpg
# LFW\lfw_changed\Tung_Chee-hwa\3.jpg
# LFW\lfw_changed\Bono\0.jpg
# LFW\lfw_changed\Woody_Allen\3.jpg
# LFW\lfw_changed\Woody_Allen\0.jpg
# LFW\lfw_changed\Tassos_Papadopoulos\2.jpg
# LFW\lfw_changed\Kim_Ryong-sung\6.jpg
# LFW\lfw_changed\Kim_Ryong-sung\3.jpg
# LFW\lfw_changed\William_Bulger\2.jpg
# LFW\lfw_changed\Donald_Rumsfeld\0.jpg
# LFW\lfw_changed\Donald_Rumsfeld\8.jpg
# LFW\lfw_changed\Coretta_Scott_King\0.jpg
# LFW\lfw_changed\Julianne_Moore\7.jpg
# LFW\lfw_changed\Julianne_Moore\3.jpg
# LFW\lfw_changed\Martha_Stewart\4.jpg
# LFW\lfw_changed\Christopher_Walken\1.jpg
# LFW\lfw_changed\Christopher_Walken\0.jpg
# LFW\lfw_changed\Paul_Sarbanes\0.jpg
# LFW\lfw_changed\Vladimir_Putin\8.jpg
# LFW\lfw_changed\Vladimir_Putin\7.jpg
# LFW\lfw_changed\Faye_Dunaway\0.jpg
# LFW\lfw_changed\Rainer_Schuettler\2.jpg
# LFW\lfw_changed\Rainer_Schuettler\3.jpg
# LFW\lfw_changed\JK_Rowling\0.jpg
# LFW\lfw_changed\Bob_Stoops\0.jpg
# LFW\lfw_changed\Bob_Stoops\3.jpg
# LFW\lfw_changed\Lou_Piniella\2.jpg
# LFW\lfw_changed\Sergio_Vieira_De_Mello\7.jpg
# LFW\lfw_changed\Sergio_Vieira_De_Mello\3.jpg
# LFW\lfw_changed\Jan-Michael_Gambill\0.jpg
# LFW\lfw_changed\Mahmoud_Abbas\2.jpg
# LFW\lfw_changed\Mahmoud_Abbas\7.jpg
# LFW\lfw_changed\Paul_Tagliabue\0.jpg
# LFW\lfw_changed\Amelie_Mauresmo\8.jpg
# LFW\lfw_changed\Amelie_Mauresmo\4.jpg
# LFW\lfw_changed\Anne_Krueger\0.jpg
# LFW\lfw_changed\Jean-David_Levitte\8.jpg
# LFW\lfw_changed\Jean-David_Levitte\2.jpg
# LFW\lfw_changed\Scott_Peterson\2.jpg
# LFW\lfw_changed\Mohamed_ElBaradei\3.jpg
# LFW\lfw_changed\Mohamed_ElBaradei\1.jpg
# LFW\lfw_changed\Nadia_Petrova\1.jpg
# LFW\lfw_changed\Michael_Chang\2.jpg
# LFW\lfw_changed\Michael_Chang\3.jpg
# LFW\lfw_changed\Jon_Gruden\4.jpg
# LFW\lfw_changed\Jason_Kidd\4.jpg
# LFW\lfw_changed\Jason_Kidd\7.jpg
# LFW\lfw_changed\Fayssal_Mekdad\3.jpg
# LFW\lfw_changed\Carlos_Moya\7.jpg
# LFW\lfw_changed\Carlos_Moya\8.jpg
# LFW\lfw_changed\Jeb_Bush\2.jpg
# LFW\lfw_changed\Gloria_Macapagal_Arroyo\7.jpg
# LFW\lfw_changed\Gloria_Macapagal_Arroyo\5.jpg
# LFW\lfw_changed\James_Gandolfini\1.jpg
# LFW\lfw_changed\Donald_Rumsfeld\0.jpg
# LFW\lfw_changed\Donald_Rumsfeld\1.jpg
# LFW\lfw_changed\Nestor_Kirchner\27.jpg
# LFW\lfw_changed\Bill_Simon\3.jpg
# LFW\lfw_changed\Bill_Simon\8.jpg
# LFW\lfw_changed\David_Heymann\0.jpg
# LFW\lfw_changed\Muhammad_Ali\5.jpg
# LFW\lfw_changed\Muhammad_Ali\7.jpg
# LFW\lfw_changed\Shimon_Peres\2.jpg
# LFW\lfw_changed\Halle_Berry\3.jpg
# LFW\lfw_changed\Halle_Berry\4.jpg
# LFW\lfw_changed\Rupert_Grint\1.jpg
# LFW\lfw_changed\John_McCain\0.jpg
# LFW\lfw_changed\John_McCain\3.jpg
# LFW\lfw_changed\Heath_Ledger\3.jpg
# LFW\lfw_changed\Abdullah_Gul\2.jpg
# LFW\lfw_changed\Abdullah_Gul\7.jpg
# LFW\lfw_changed\Cameron_Diaz\4.jpg
# LFW\lfw_changed\Meryl_Streep\7.jpg
# LFW\lfw_changed\Meryl_Streep\5.jpg
# LFW\lfw_changed\Roy_Williams\2.jpg
# LFW\lfw_changed\Jim_Furyk\3.jpg
# LFW\lfw_changed\Jim_Furyk\4.jpg
# LFW\lfw_changed\Mike_Myers\1.jpg
# LFW\lfw_changed\John_Abizaid\0.jpg
# LFW\lfw_changed\John_Abizaid\2.jpg
# LFW\lfw_changed\John_Paul_II\8.jpg
# LFW\lfw_changed\Ben_Affleck\3.jpg
# LFW\lfw_changed\Ben_Affleck\4.jpg
# LFW\lfw_changed\Jelena_Dokic\2.jpg
# LFW\lfw_changed\Lleyton_Hewitt\7.jpg
# LFW\lfw_changed\Lleyton_Hewitt\6.jpg
# LFW\lfw_changed\Wayne_Ferreira\4.jpg
# LFW\lfw_changed\Nicanor_Duarte_Frutos\6.jpg
# LFW\lfw_changed\Nicanor_Duarte_Frutos\5.jpg
# LFW\lfw_changed\Andrew_Weissmann\0.jpg
# LFW\lfw_changed\Juan_Carlos_Ferrero\3.jpg
# LFW\lfw_changed\Juan_Carlos_Ferrero\0.jpg
# LFW\lfw_changed\Doris_Schroeder\0.jpg
# LFW\lfw_changed\Gerry_Adams\4.jpg
# LFW\lfw_changed\Gerry_Adams\6.jpg
# LFW\lfw_changed\Abel_Pacheco\1.jpg
# LFW\lfw_changed\Andre_Agassi\0.jpg
# LFW\lfw_changed\Andre_Agassi\7.jpg
# LFW\lfw_changed\Warren_Buffett\2.jpg
# LFW\lfw_changed\Jean-David_Levitte\1.jpg
# LFW\lfw_changed\Jean-David_Levitte\2.jpg
# LFW\lfw_changed\Thomas_OBrien\1.jpg
# LFW\lfw_changed\John_Negroponte\4.jpg
# LFW\lfw_changed\John_Negroponte\7.jpg
# LFW\lfw_changed\Julianne_Moore\15.jpg
# LFW\lfw_changed\Elsa_Zylberstein\4.jpg
# LFW\lfw_changed\Elsa_Zylberstein\1.jpg
# LFW\lfw_changed\Matt_Dillon\2.jpg
# LFW\lfw_changed\Colin_Farrell\2.jpg
# LFW\lfw_changed\Colin_Farrell\6.jpg
# LFW\lfw_changed\Ben_Affleck\2.jpg
# LFW\lfw_changed\Mohamed_ElBaradei\2.jpg
# LFW\lfw_changed\Mohamed_ElBaradei\1.jpg
# LFW\lfw_changed\Elizabeth_Dole\3.jpg
# LFW\lfw_changed\Jeb_Bush\8.jpg
# LFW\lfw_changed\Jeb_Bush\0.jpg
# LFW\lfw_changed\Don_Siegelman\0.jpg
# LFW\lfw_changed\Bill_Graham\2.jpg
# LFW\lfw_changed\Bill_Graham\3.jpg
# LFW\lfw_changed\Thomas_Fargo\3.jpg
# LFW\lfw_changed\Gray_Davis\5.jpg
# LFW\lfw_changed\Gray_Davis\3.jpg
# LFW\lfw_changed\Martin_Scorsese\6.jpg
# LFW\lfw_changed\Vladimir_Putin\0.jpg
# LFW\lfw_changed\Vladimir_Putin\8.jpg
# LFW\lfw_changed\Justin_Leonard\1.jpg
# LFW\lfw_changed\Mohammad_Khatami\3.jpg
# LFW\lfw_changed\Mohammad_Khatami\0.jpg
# LFW\lfw_changed\Fayssal_Mekdad\2.jpg
# LFW\lfw_changed\Tommy_Franks\1.jpg
# LFW\lfw_changed\Tommy_Franks\8.jpg
# LFW\lfw_changed\Bono\2.jpg
# LFW\lfw_changed\William_Macy\1.jpg
# LFW\lfw_changed\William_Macy\2.jpg
# LFW\lfw_changed\Dick_Cheney\8.jpg
# LFW\lfw_changed\Heizo_Takenaka\2.jpg
# LFW\lfw_changed\Heizo_Takenaka\0.jpg
# LFW\lfw_changed\James_Cameron\0.jpg
# LFW\lfw_changed\Thomas_OBrien\5.jpg
# LFW\lfw_changed\Thomas_OBrien\2.jpg
# LFW\lfw_changed\Yasar_Yakis\0.jpg
# LFW\lfw_changed\Michael_Jackson\6.jpg
# LFW\lfw_changed\Michael_Jackson\1.jpg
# LFW\lfw_changed\Jack_Nicholson\1.jpg
# LFW\lfw_changed\Bob_Stoops\5.jpg
# LFW\lfw_changed\Bob_Stoops\2.jpg
# LFW\lfw_changed\Lars_Von_Trier\2.jpg
# LFW\lfw_changed\Robert_Redford\5.jpg
# LFW\lfw_changed\Robert_Redford\6.jpg
# LFW\lfw_changed\Mark_Richt\1.jpg
# LFW\lfw_changed\Paul_Martin\3.jpg
# LFW\lfw_changed\Paul_Martin\2.jpg
# LFW\lfw_changed\Kalpana_Chawla\1.jpg
# LFW\lfw_changed\Gustavo_Kuerten\0.jpg
# LFW\lfw_changed\Gustavo_Kuerten\1.jpg
# LFW\lfw_changed\Ronald_Reagan\1.jpg
# LFW\lfw_changed\Hu_Jintao\2.jpg
# LFW\lfw_changed\Hu_Jintao\4.jpg
# LFW\lfw_changed\Carmen_Electra\5.jpg
# LFW\lfw_changed\Elton_John\2.jpg
# LFW\lfw_changed\Elton_John\0.jpg
# LFW\lfw_changed\Ali_Naimi\4.jpg
# LFW\lfw_changed\Meryl_Streep\0.jpg
# LFW\lfw_changed\Meryl_Streep\1.jpg
# LFW\lfw_changed\Hitomi_Soga\3.jpg
# LFW\lfw_changed\Amelia_Vega\0.jpg
# LFW\lfw_changed\Amelia_Vega\5.jpg
# LFW\lfw_changed\Doug_Melvin\0.jpg
# LFW\lfw_changed\Tom_Ridge\2.jpg
# LFW\lfw_changed\Tom_Ridge\1.jpg
# LFW\lfw_changed\Alvaro_Noboa\0.jpg
# LFW\lfw_changed\John_Paul_II\6.jpg
# LFW\lfw_changed\John_Paul_II\1.jpg
# LFW\lfw_changed\Lisa_Marie_Presley\0.jpg
# LFW\lfw_changed\Tony_Blair\2.jpg
# LFW\lfw_changed\Tony_Blair\6.jpg
# LFW\lfw_changed\Justin_Leonard\0.jpg
# LFW\lfw_changed\Dennis_Kucinich\4.jpg
# LFW\lfw_changed\Dennis_Kucinich\2.jpg
# LFW\lfw_changed\Dianne_Feinstein\2.jpg
# LFW\lfw_changed\Keanu_Reeves\2.jpg
# LFW\lfw_changed\Keanu_Reeves\3.jpg
# LFW\lfw_changed\Alejandro_Toledo\11.jpg
# LFW\lfw_changed\Richard_Gephardt\0.jpg
# LFW\lfw_changed\Richard_Gephardt\6.jpg
# LFW\lfw_changed\Petria_Thomas\2.jpg
# LFW\lfw_changed\Pierre_Pettigrew\0.jpg
# LFW\lfw_changed\Pierre_Pettigrew\1.jpg
# LFW\lfw_changed\Daniel_Radcliffe\0.jpg
# LFW\lfw_changed\Kate_Hudson\5.jpg
# LFW\lfw_changed\Kate_Hudson\6.jpg
# LFW\lfw_changed\Anne_Krueger\0.jpg
# LFW\lfw_changed\JK_Rowling\1.jpg
# LFW\lfw_changed\JK_Rowling\0.jpg
# LFW\lfw_changed\Aaron_Peirsol\1.jpg
# LFW\lfw_changed\Jennifer_Connelly\2.jpg
# LFW\lfw_changed\Jennifer_Connelly\1.jpg
# LFW\lfw_changed\Mary-Kate_Olsen\2.jpg
# LFW\lfw_changed\Alvaro_Uribe\0.jpg
# LFW\lfw_changed\Alvaro_Uribe\2.jpg
# LFW\lfw_changed\Rainer_Schuettler\4.jpg
# LFW\lfw_changed\Fernando_Gonzalez\2.jpg
# LFW\lfw_changed\Fernando_Gonzalez\4.jpg
# LFW\lfw_changed\Gil_de_Ferran\0.jpg
# LFW\lfw_changed\Amelie_Mauresmo\3.jpg
# LFW\lfw_changed\Amelie_Mauresmo\5.jpg
# LFW\lfw_changed\Mark_Wahlberg\2.jpg
# LFW\lfw_changed\Robert_Zoellick\5.jpg
# LFW\lfw_changed\Robert_Zoellick\1.jpg
# LFW\lfw_changed\Greg_Rusedski\0.jpg
# LFW\lfw_changed\Harrison_Ford\7.jpg
# LFW\lfw_changed\Harrison_Ford\3.jpg
# LFW\lfw_changed\Fernando_Vargas\1.jpg
# LFW\lfw_changed\Sam_Torrance\0.jpg
# LFW\lfw_changed\Sam_Torrance\1.jpg
# LFW\lfw_changed\Susilo_Bambang_Yudhoyono\3.jpg
# LFW\lfw_changed\Joan_Laporta\1.jpg
# LFW\lfw_changed\Joan_Laporta\6.jpg
# LFW\lfw_changed\Kate_Winslet\2.jpg
# LFW\lfw_changed\Condoleezza_Rice\8.jpg
# LFW\lfw_changed\Condoleezza_Rice\5.jpg
# LFW\lfw_changed\Petria_Thomas\1.jpg
# LFW\lfw_changed\Tom_Cruise\2.jpg
# LFW\lfw_changed\Tom_Cruise\0.jpg
# LFW\lfw_changed\Petria_Thomas\2.jpg
# LFW\lfw_changed\Julianne_Moore\7.jpg
# LFW\lfw_changed\Julianne_Moore\8.jpg
# LFW\lfw_changed\Jon_Corzine\1.jpg
# LFW\lfw_changed\Gerhard_Schroeder\7.jpg
# LFW\lfw_changed\Gerhard_Schroeder\6.jpg
# LFW\lfw_changed\Sharon_Osbourne\1.jpg
# LFW\lfw_changed\Mahathir_Mohamad\4.jpg
# LFW\lfw_changed\Mahathir_Mohamad\5.jpg
# LFW\lfw_changed\Jesse_Jackson\8.jpg
# LFW\lfw_changed\Jeong_Se-hyun\3.jpg
# LFW\lfw_changed\Jeong_Se-hyun\0.jpg
# LFW\lfw_changed\Bono\1.jpg
# LFW\lfw_changed\Meryl_Streep\5.jpg
# LFW\lfw_changed\Meryl_Streep\1.jpg
# LFW\lfw_changed\Lenny_Wilkens\2.jpg
# LFW\lfw_changed\Abdullah_Gul\3.jpg
# LFW\lfw_changed\Abdullah_Gul\0.jpg
# LFW\lfw_changed\Gerhard_Schroeder\37.jpg
# LFW\lfw_changed\Keanu_Reeves\7.jpg
# LFW\lfw_changed\Keanu_Reeves\8.jpg
# LFW\lfw_changed\Kelly_Clarkson\2.jpg
# LFW\lfw_changed\Gordon_Brown\0.jpg
# LFW\lfw_changed\Gordon_Brown\5.jpg
# LFW\lfw_changed\Choi_Sung-hong\0.jpg
# LFW\lfw_changed\John_Kerry\6.jpg
# LFW\lfw_changed\John_Kerry\5.jpg
# LFW\lfw_changed\Roh_Moo-hyun\20.jpg
# LFW\lfw_changed\Paul_Bremer\8.jpg
# LFW\lfw_changed\Paul_Bremer\7.jpg
# LFW\lfw_changed\Oxana_Fedorova\1.jpg
# LFW\lfw_changed\Javier_Solana\2.jpg
# LFW\lfw_changed\Javier_Solana\6.jpg
# LFW\lfw_changed\Hu_Jintao\9.jpg
# LFW\lfw_changed\Thaksin_Shinawatra\0.jpg
# LFW\lfw_changed\Thaksin_Shinawatra\2.jpg
# LFW\lfw_changed\Jose_Serra\0.jpg
# LFW\lfw_changed\Tung_Chee-hwa\1.jpg
# LFW\lfw_changed\Tung_Chee-hwa\4.jpg
# LFW\lfw_changed\Clare_Short\0.jpg
# LFW\lfw_changed\Ray_Romano\7.jpg
# LFW\lfw_changed\Ray_Romano\5.jpg
# LFW\lfw_changed\Candie_Kung\3.jpg
# LFW\lfw_changed\Kalpana_Chawla\3.jpg
# LFW\lfw_changed\Kalpana_Chawla\1.jpg
# LFW\lfw_changed\Sadie_Frost\2.jpg
# LFW\lfw_changed\Sean_OKeefe\2.jpg
# LFW\lfw_changed\Sean_OKeefe\1.jpg
# LFW\lfw_changed\Abid_Hamid_Mahmud_Al-Tikriti\1.jpg
# LFW\lfw_changed\Atal_Bihari_Vajpayee\5.jpg
# LFW\lfw_changed\Atal_Bihari_Vajpayee\8.jpg
# LFW\lfw_changed\Yevgeny_Kafelnikov\2.jpg
# LFW\lfw_changed\Joe_Lieberman\6.jpg
# LFW\lfw_changed\Joe_Lieberman\5.jpg
# LFW\lfw_changed\Theresa_May\1.jpg
# LFW\lfw_changed\Serena_Williams\3.jpg
# LFW\lfw_changed\Serena_Williams\2.jpg
# LFW\lfw_changed\Prince_Charles\4.jpg
# LFW\lfw_changed\Yoriko_Kawaguchi\2.jpg
# LFW\lfw_changed\Yoriko_Kawaguchi\5.jpg
# LFW\lfw_changed\Arnoldo_Aleman\3.jpg
# LFW\lfw_changed\Robert_De_Niro\4.jpg
# LFW\lfw_changed\Robert_De_Niro\2.jpg
# LFW\lfw_changed\William_Bratton\0.jpg
# LFW\lfw_changed\Elton_John\2.jpg
# LFW\lfw_changed\Elton_John\1.jpg
# LFW\lfw_changed\Anders_Fogh_Rasmussen\2.jpg
# LFW\lfw_changed\Tim_Allen\0.jpg
# LFW\lfw_changed\Tim_Allen\1.jpg
# LFW\lfw_changed\Madonna\0.jpg
# LFW\lfw_changed\Mariah_Carey\0.jpg
# LFW\lfw_changed\Mariah_Carey\1.jpg
# LFW\lfw_changed\Chan_Gailey\1.jpg
# LFW\lfw_changed\Chanda_Rubin\2.jpg
# LFW\lfw_changed\Chanda_Rubin\1.jpg
# LFW\lfw_changed\Tom_Hanks\9.jpg
# LFW\lfw_changed\Edmund_Stoiber\4.jpg
# LFW\lfw_changed\Edmund_Stoiber\7.jpg
# LFW\lfw_changed\James_Gandolfini\2.jpg
# LFW\lfw_changed\Jennifer_Capriati\0.jpg
# LFW\lfw_changed\Jennifer_Capriati\2.jpg
# LFW\lfw_changed\Martina_Hingis\2.jpg
# LFW\lfw_changed\Hugh_Grant\2.jpg
# LFW\lfw_changed\Hugh_Grant\0.jpg
# LFW\lfw_changed\Rita_Grande\1.jpg
# LFW\lfw_changed\Wen_Jiabao\8.jpg
# LFW\lfw_changed\Wen_Jiabao\5.jpg
# LFW\lfw_changed\Carson_Palmer\1.jpg
# LFW\lfw_changed\Celine_Dion\4.jpg
# LFW\lfw_changed\Celine_Dion\1.jpg
# LFW\lfw_changed\Ed_Rosenthal\0.jpg
# LFW\lfw_changed\Cruz_Bustamante\2.jpg
# LFW\lfw_changed\Cruz_Bustamante\0.jpg
# LFW\lfw_changed\Pervez_Musharraf\6.jpg
# LFW\lfw_changed\John_Abizaid\5.jpg
# LFW\lfw_changed\John_Abizaid\4.jpg
# LFW\lfw_changed\Gustavo_Kuerten\1.jpg
# LFW\lfw_changed\Lance_Armstrong\2.jpg
# LFW\lfw_changed\Lance_Armstrong\5.jpg
# LFW\lfw_changed\Christopher_Reeve\2.jpg
# LFW\lfw_changed\Oswaldo_Paya\3.jpg
# LFW\lfw_changed\Oswaldo_Paya\0.jpg
# LFW\lfw_changed\Andre_Agassi\24.jpg
# LFW\lfw_changed\Mike_Weir\5.jpg
# LFW\lfw_changed\Mike_Weir\0.jpg
# LFW\lfw_changed\Catherine_Deneuve\2.jpg
# LFW\lfw_changed\Carlos_Moya\5.jpg
# LFW\lfw_changed\Carlos_Moya\2.jpg
# LFW\lfw_changed\Jim_Furyk\4.jpg
# LFW\lfw_changed\Mahathir_Mohamad\6.jpg
# LFW\lfw_changed\Mahathir_Mohamad\4.jpg
# LFW\lfw_changed\LK_Advani\0.jpg
# LFW\lfw_changed\Alejandro_Toledo\4.jpg
# LFW\lfw_changed\Alejandro_Toledo\5.jpg
# LFW\lfw_changed\Alexandra_Stevenson\0.jpg
# LFW\lfw_changed\Paul_Wolfowitz\1.jpg
# LFW\lfw_changed\Paul_Wolfowitz\5.jpg
# LFW\lfw_changed\John_Howard\12.jpg
# LFW\lfw_changed\Edward_Lu\4.jpg
# LFW\lfw_changed\Edward_Lu\2.jpg
# LFW\lfw_changed\Carlos_Vives\3.jpg
# LFW\lfw_changed\Gerhard_Schroeder\1.jpg
# LFW\lfw_changed\Gerhard_Schroeder\0.jpg
# LFW\lfw_changed\Christopher_Walken\1.jpg
# LFW\lfw_changed\Edwina_Currie\0.jpg
# LFW\lfw_changed\Edwina_Currie\1.jpg
# LFW\lfw_changed\Tony_Shalhoub\2.jpg
# LFW\lfw_changed\GL_Peiris\2.jpg
# LFW\lfw_changed\GL_Peiris\0.jpg
# LFW\lfw_changed\Joschka_Fischer\11.jpg
# LFW\lfw_changed\Jose_Maria_Aznar\2.jpg
# LFW\lfw_changed\Jose_Maria_Aznar\5.jpg
# LFW\lfw_changed\Jonathan_Edwards\7.jpg
# LFW\lfw_changed\Richard_Virenque\4.jpg
# LFW\lfw_changed\Richard_Virenque\6.jpg
# LFW\lfw_changed\Pamela_Anderson\0.jpg
# LFW\lfw_changed\Atal_Bihari_Vajpayee\4.jpg
# LFW\lfw_changed\Atal_Bihari_Vajpayee\1.jpg
# LFW\lfw_changed\Arturo_Gatti\1.jpg
# LFW\lfw_changed\Muhammad_Ali\8.jpg
# LFW\lfw_changed\Muhammad_Ali\5.jpg
# LFW\lfw_changed\Jonathan_Edwards\6.jpg
# LFW\lfw_changed\Lleyton_Hewitt\8.jpg
# LFW\lfw_changed\Lleyton_Hewitt\0.jpg
# LFW\lfw_changed\Rick_Stansbury\1.jpg
# LFW\lfw_changed\Richard_Armitage\5.jpg
# LFW\lfw_changed\Richard_Armitage\7.jpg
# LFW\lfw_changed\Carlos_Ruiz\2.jpg
# LFW\lfw_changed\Mahathir_Mohamad\3.jpg
# LFW\lfw_changed\Mahathir_Mohamad\0.jpg
# LFW\lfw_changed\Ana_Palacio\5.jpg
# LFW\lfw_changed\Jerry_Springer\0.jpg
# LFW\lfw_changed\Jerry_Springer\1.jpg
# LFW\lfw_changed\Bono\1.jpg
# LFW\lfw_changed\Carlos_Moya\5.jpg
# LFW\lfw_changed\Carlos_Moya\7.jpg
# LFW\lfw_changed\Kjell_Magne_Bondevik\0.jpg
# LFW\lfw_changed\George_W_Bush\3.jpg
# LFW\lfw_changed\George_W_Bush\6.jpg
# LFW\lfw_changed\Condoleezza_Rice\10.jpg
# LFW\lfw_changed\Jennifer_Lopez\1.jpg
# LFW\lfw_changed\Jennifer_Lopez\8.jpg
# LFW\lfw_changed\William_Bulger\2.jpg
# LFW\lfw_changed\Binyamin_Ben-Eliezer\3.jpg
# LFW\lfw_changed\Binyamin_Ben-Eliezer\1.jpg
# LFW\lfw_changed\David_Heymann\2.jpg
# LFW\lfw_changed\Gonzalo_Sanchez_de_Lozada\0.jpg
# LFW\lfw_changed\Gonzalo_Sanchez_de_Lozada\8.jpg
# LFW\lfw_changed\Mohamed_ElBaradei\6.jpg
# LFW\lfw_changed\Tom_Ridge\5.jpg
# LFW\lfw_changed\Tom_Ridge\7.jpg
# LFW\lfw_changed\Anna_Kournikova\6.jpg
# LFW\lfw_changed\Lleyton_Hewitt\6.jpg
# LFW\lfw_changed\Lleyton_Hewitt\4.jpg
# LFW\lfw_changed\Vincent_Gallo\1.jpg
# LFW\lfw_changed\Nancy_Pelosi\2.jpg
# LFW\lfw_changed\Nancy_Pelosi\3.jpg
# LFW\lfw_changed\Vanessa_Redgrave\4.jpg
# LFW\lfw_changed\Thomas_OBrien\4.jpg
# LFW\lfw_changed\Thomas_OBrien\3.jpg
# LFW\lfw_changed\Sila_Calderon\0.jpg
# LFW\lfw_changed\Ray_Romano\4.jpg
# LFW\lfw_changed\Ray_Romano\7.jpg
# LFW\lfw_changed\Petria_Thomas\2.jpg
# LFW\lfw_changed\Angela_Bassett\2.jpg
# LFW\lfw_changed\Angela_Bassett\0.jpg
# LFW\lfw_changed\Benazir_Bhutto\4.jpg
# LFW\lfw_changed\Tom_Harkin\3.jpg
# LFW\lfw_changed\Tom_Harkin\2.jpg
# LFW\lfw_changed\Spencer_Abraham\15.jpg
# LFW\lfw_changed\Fidel_Castro\0.jpg
# LFW\lfw_changed\Fidel_Castro\7.jpg
# LFW\lfw_changed\Eliane_Karp\1.jpg
# LFW\lfw_changed\Ali_Naimi\1.jpg
# LFW\lfw_changed\Ali_Naimi\5.jpg
# LFW\lfw_changed\Ray_Romano\5.jpg
# LFW\lfw_changed\Colin_Farrell\6.jpg
# LFW\lfw_changed\Colin_Farrell\1.jpg
# LFW\lfw_changed\David_Nalbandian\6.jpg
# LFW\lfw_changed\Clint_Eastwood\2.jpg
# LFW\lfw_changed\Clint_Eastwood\0.jpg
# LFW\lfw_changed\GL_Peiris\2.jpg
# LFW\lfw_changed\Arnoldo_Aleman\1.jpg
# LFW\lfw_changed\Arnoldo_Aleman\2.jpg
# LFW\lfw_changed\Akbar_Hashemi_Rafsanjani\2.jpg
# LFW\lfw_changed\Pete_Sampras\3.jpg
# LFW\lfw_changed\Pete_Sampras\8.jpg
# LFW\lfw_changed\John_Edwards\5.jpg
# LFW\lfw_changed\Vicente_Fox\0.jpg
# LFW\lfw_changed\Vicente_Fox\6.jpg
# LFW\lfw_changed\Jake_Gyllenhaal\4.jpg
# LFW\lfw_changed\Sergio_Vieira_De_Mello\6.jpg
# LFW\lfw_changed\Sergio_Vieira_De_Mello\0.jpg
# LFW\lfw_changed\Elijah_Wood\2.jpg
# LFW\lfw_changed\Tariq_Aziz\2.jpg
# LFW\lfw_changed\Tariq_Aziz\3.jpg
# LFW\lfw_changed\Tim_Conway\2.jpg
# LFW\lfw_changed\John_Manley\3.jpg
# LFW\lfw_changed\John_Manley\4.jpg
# LFW\lfw_changed\Ben_Curtis\1.jpg
# LFW\lfw_changed\Tiger_Woods\4.jpg
# LFW\lfw_changed\Tiger_Woods\5.jpg
# LFW\lfw_changed\Michael_Chiklis\1.jpg
# LFW\lfw_changed\Pete_Sampras\3.jpg
# LFW\lfw_changed\Pete_Sampras\5.jpg
# LFW\lfw_changed\Jean-Francois_Pontal\2.jpg
# LFW\lfw_changed\Fidel_Castro\4.jpg
# LFW\lfw_changed\Fidel_Castro\3.jpg
# LFW\lfw_changed\Ray_Romano\2.jpg
# LFW\lfw_changed\Rubens_Barrichello\7.jpg
# LFW\lfw_changed\Rubens_Barrichello\0.jpg
# LFW\lfw_changed\Tim_Allen\1.jpg
# LFW\lfw_changed\Boris_Becker\0.jpg
# LFW\lfw_changed\Boris_Becker\4.jpg
# LFW\lfw_changed\Billy_Crystal\4.jpg
# LFW\lfw_changed\Mike_Weir\0.jpg
# LFW\lfw_changed\Mike_Weir\5.jpg
# LFW\lfw_changed\Jim_Carrey\0.jpg
# LFW\lfw_changed\Richard_Virenque\4.jpg
# LFW\lfw_changed\Richard_Virenque\0.jpg
# LFW\lfw_changed\Tim_Henman\6.jpg
# LFW\lfw_changed\Donald_Rumsfeld\4.jpg
# LFW\lfw_changed\Donald_Rumsfeld\5.jpg
# LFW\lfw_changed\Martin_McGuinness\1.jpg
# LFW\lfw_changed\Kim_Dae-jung\0.jpg
# LFW\lfw_changed\Kim_Dae-jung\5.jpg
# LFW\lfw_changed\Christine_Baumgartner\1.jpg
# LFW\lfw_changed\Gonzalo_Sanchez_de_Lozada\1.jpg
# LFW\lfw_changed\Gonzalo_Sanchez_de_Lozada\0.jpg
# LFW\lfw_changed\Woody_Allen\0.jpg
# LFW\lfw_changed\Megawati_Sukarnoputri\4.jpg
# LFW\lfw_changed\Megawati_Sukarnoputri\1.jpg
# LFW\lfw_changed\Sonia_Gandhi\2.jpg
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[44], line 1
# ----> 1 trainSiameseModel(trainDataset, testTriplets, epochs=2)
#
# Cell In[38], line 10, in trainSiameseModel(trainDataset, testTriplets, epochs, batchSize)
#       8 epochLoss = []
#       9 for data in getTripletsBatch(trainTriplets, size=batchSize):
# ---> 10   loss = siameseModel.train_on_batch(data)
#      11   epochLoss.append(loss)
#      12 epochLoss = sum(epochLoss)/len(epochLoss)
#
# File c:\Users\Jaroslaw\AppData\Local\Programs\Python\Python311\Lib\site-packages\keras\src\backend\tensorflow\trainer.py:540, in TensorFlowTrainer.train_on_batch(self, x, y, sample_weight, class_weight, return_dict)
#     537 def data():
#     538     yield (x, y, sample_weight)
# --> 540 logs = self.train_function(data())
#     541 logs = tree.map_structure(lambda x: np.array(x), logs)
#     542 if return_dict:
#
# File c:\Users\Jaroslaw\AppData\Local\Programs\Python\Python311\Lib\site-packages\tensorflow\python\util\traceback_utils.py:153, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     151 except Exception as e:
#     152   filtered_tb = _process_traceback_frames(e.__traceback__)
# --> 153   raise e.with_traceback(filtered_tb) from None
#     154 finally:
#     155   del filtered_tb
#
# File c:\Users\Jaroslaw\AppData\Local\Programs\Python\Python311\Lib\site-packages\keras\src\backend\tensorflow\trainer.py:117, in TensorFlowTrainer.make_train_function.<locals>.one_step_on_iterator(iterator)
#     115 """Runs a single training step given a Dataset iterator."""
#     116 data = next(iterator)
# --> 117 outputs = self.distribute_strategy.run(
#     118     one_step_on_data, args=(data,)
#     119 )
#     120 outputs = reduce_per_replica(
#     121     outputs,
#     122     self.distribute_strategy,
#     123     reduction="auto",
#     124 )
#     125 return outputs
#
# File c:\Users\Jaroslaw\AppData\Local\Programs\Python\Python311\Lib\site-packages\keras\src\backend\tensorflow\trainer.py:104, in TensorFlowTrainer.make_train_function.<locals>.one_step_on_data(data)
#     101 @tf.autograph.experimental.do_not_convert
#     102 def one_step_on_data(data):
#     103     """Runs a single training step on a batch of data."""
# --> 104     return self.train_step(data)
#
# Cell In[34], line 15, in SiameseModel.train_step(self, data)
#      13 def train_step(self, data):
#      14   with tf.GradientTape() as tape:
# ---> 15     loss = self._compute_loss(data)
#      17   gradients = tape.gradient(loss, self.siameseNetwork.trainable_weights)
#      18   self.optimizer.apply_gradients(zip(gradients, self.siameseNetwork.trainable_weights))
#
# Cell In[34], line 28, in SiameseModel._compute_loss(self, data)
#      27 def _compute_loss(self, data):
# ---> 28   anchorPositiveDistance, anchorNegativeDistance = self.siameseNetwork(data)
#      29   loss = tf.maximum(anchorPositiveDistance - anchorNegativeDistance + self.margin, 0.0)
#      30   return loss
#
# File c:\Users\Jaroslaw\AppData\Local\Programs\Python\Python311\Lib\site-packages\keras\src\utils\traceback_utils.py:122, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     119     filtered_tb = _process_traceback_frames(e.__traceback__)
#     120     # To get the full stack trace, call:
#     121     # `keras.config.disable_traceback_filtering()`
# --> 122     raise e.with_traceback(filtered_tb) from None
#     123 finally:
#     124     del filtered_tb
#
# File c:\Users\Jaroslaw\AppData\Local\Programs\Python\Python311\Lib\site-packages\keras\src\layers\layer.py:1492, in CallSpec.__init__(self, signature, args, kwargs)
#    1490             nested_tensor_arg_names.append(name)
#    1491         elif any(is_backend_tensor_or_symbolic(x) for x in flat_values):
# -> 1492             raise ValueError(
#    1493                 "In a nested call() argument, "
#    1494                 "you cannot mix tensors and non-tensors. "
#    1495                 "Received invalid mixed argument: "
#    1496                 f"{name}={value}"
#    1497             )
#    1498 self.arguments_dict = arg_dict
#    1499 self.argument_names = arg_names
#
# ValueError: In a nested call() argument, you cannot mix tensors and non-tensors. Received invalid mixed argument: inputs=([<tf.Tensor 'data:0' shape=(256, 250, 250, 3) dtype=float32>, <tf.Tensor 'data_1:0' shape=(256, 250, 250, 3) dtype=float32>, <tf.Tensor 'data_2:0' shape=(256, 250, 250, 3) dtype=float32>], None, None)
